# %% [markdown]
# # 5. Blokkprogrammering

# %% [markdown]
# ### Oppgave 1

# %%
from IPython.display import Image
Image("bilder_kap5/5.12.1.png")

# %% [markdown]
# ### Oppgave 2

# %%
from IPython.display import Image
Image("bilder_kap5/5.12.2.png")

# %% [markdown]
# ### Oppgave 3

# %%
from IPython.display import Image
Image("bilder_kap5/5.12.3.png")

# %% [markdown]
# ### Oppgave 4

# %%
from IPython.display import Image
Image("bilder_kap5/5.12.4.png")

# %% [markdown]
# ### Oppgave 5

# %%
from IPython.display import Image
Image("bilder_kap5/5.12.5.png")

# %% [markdown]
# ### Oppgave 6

# %%
from IPython.display import Image
Image("bilder_kap5/5.12.6.png")
